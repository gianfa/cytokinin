# %%
import os
import json
import numpy as np
import pandas as pd

# %%
# # API define_data

# def problem_type(): # ('classification', 'regression', 'tabular')
#     pass

# def set_type(): #('train')
#     pass

# def define_x(): pass
# def define_y(): pass
# def define_xy(): pass
# #what if from dataframe?

# def add_continous():
#     pass

# def add_table():
#     pass

# %%
# # API datasets

# # Example
# imgs = take_data('images').from_folder
# cars = create_dataset('images').named('cars').from_folder('./cars/').labeled_as_its_folder()
# cars.add_files('images').from_folder('./cars2/')

# motos = create_dataset('images').named('motos').from_many_folders(folderlist)



# cars = create_dataset('images') # Dataset => df

# cars.named(datasetname)

# cars.from_folder(foldername)
#     .from_filenames(fnames, ignore, extensions)
    
    
# #labels
# cars.labeled_as()
#     .labeled_as_its_folder()
#     .labeled_as_images_names()
#     .labeled_as_part_of_images_names()
    
#     .labeled_from_csv()
#     .labeled_from_.........


# targetType = ['array_list', 'text_list']

# cars.add_target_set(astype=targetType) 

# cars_labels = cl = dataset('labels')
# cl.name_all_as(NAME)

# %% [markdown]
# _______________________

# %% [markdown]
# ### Go

# %%
import os
import json
import numpy as np
import pandas as pd

# %%
import cytokine as ck

# %%
IMGS = './cytokine/tests/mocks/imgs/'

flist = []
for root, dirs, files in os.walk(IMGS, topdown=False):
    for f in files:
        flist.append(os.path.join(root, f))

# %%
from cytokine.data import take_data

# if a: del a
a = take_data('images')
# a.take_data('images')

# %% [markdown]
# From list

# %%
a.filesnames
# Out:
# Series([], Name: data15775542847713625, dtype: float64)

# %%
a.store_filesnames_from_list(flist)

# %%
a.filesnames[2]
# Out:
# './cytokine/tests/mocks/imgs/stone/stone_20.jpeg'

# %% [markdown]
# From DataFrame

# %%
df = pd.DataFrame({'files': flist})

# %%
b = take_data('images')
b.store_filesnames_from_df(df, 'files') #hold uniques

# %% [markdown]
# From folder

# %%
b = take_data('images').store_filesnames_from_folder('./cytokine/tests/mocks/imgs/dog')
b.filesnames.head()
# Out:
# 0      ./cytokine/tests/mocks/imgs/dog/dog_5.png
# 1     ./cytokine/tests/mocks/imgs/dog/dog_16.jpg
# 2    ./cytokine/tests/mocks/imgs/dog/dog_32.jpeg
# 3     ./cytokine/tests/mocks/imgs/dog/dog_17.jpg
# 4     ./cytokine/tests/mocks/imgs/dog/dog_22.jpg
# Name: data15775542864287307, dtype: object

# %% [markdown]
# Print

# %%
print(b)
# Out:
# Object <class 'cytokine.data.Data'>, of data type "images", having 36 file paths records.

# %%
b.filesnames.head()
# Out:
# 0      ./cytokine/tests/mocks/imgs/dog/dog_5.png
# 1     ./cytokine/tests/mocks/imgs/dog/dog_16.jpg
# 2    ./cytokine/tests/mocks/imgs/dog/dog_32.jpeg
# 3     ./cytokine/tests/mocks/imgs/dog/dog_17.jpg
# 4     ./cytokine/tests/mocks/imgs/dog/dog_22.jpg
# Name: data15775542864287307, dtype: object

# %% [markdown]
# To

# %%
b.to('arrays')[:10]
# Out:
# [array([[[121,  91,  67],
#          [120,  90,  66],
#          [120,  90,  66],
#          ...,
#          [119,  89,  68],
#          [117,  87,  66],
#          [119,  89,  68]],
#
#         [[120,  90,  66],
#          [120,  90,  66],
#          [122,  92,  68],
#          ...,
#          [117,  87,  66],
#          [120,  90,  69],
#          [116,  90,  66]],
#
#         [[119,  89,  65],
#          [118,  88,  64],
#          [120,  90,  66],
#          ...,
#          [118,  88,  67],
#          [120,  90,  69],
#          [116,  90,  67]],
#
#         ...,
#
#         [[100, 137, 158],
#          [ 95, 126, 150],
#          [ 96, 129, 153],
#          ...,
#          [ 67,  91, 112],
#          [ 58,  76,  98],
#          [ 39,  60,  76]],
#
#         [[ 97, 129, 150],
#          [ 96, 127, 151],
#          [ 89, 124, 144],
#          ...,
#          [ 53,  84, 107],
#          [ 61,  87, 114],
#          [ 56,  99, 126]],
#
#         [[ 94, 124, 146],
#          [ 96, 129, 153],
#          [102, 139, 160],
#          ...,
#          [ 49, 106, 131],
#          [ 60, 122, 148],
#          [ 68, 134, 158]]], dtype=uint8), array([[[135, 139, 128],
#          [135, 139, 128],
#          [134, 138, 127],
#          ...,
#          [158, 156, 146],
#          [158, 156, 146],
#          [158, 156, 146]],
#
#         [[135, 139, 128],
#          [134, 138, 127],
#          [134, 138, 127],
#          ...,
#          [158, 156, 146],
#          [158, 156, 146],
#          [158, 156, 146]],
#
#         [[134, 138, 127],
#          [134, 138, 127],
#          [135, 139, 128],
#          ...,
#          [158, 156, 146],
#          [158, 156, 146],
#          [158, 156, 146]],
#
#         ...,
#
#         [[196, 201, 202],
#          [196, 201, 202],
#          [196, 201, 202],
#          ...,
#          [186, 195, 198],
#          [184, 196, 198],
#          [184, 196, 198]],
#
#         [[196, 201, 202],
#          [196, 201, 202],
#          [197, 202, 203],
#          ...,
#          [185, 194, 197],
#          [183, 195, 197],
#          [183, 195, 197]],
#
#         [[196, 201, 202],
#          [197, 202, 203],
#          [197, 202, 203],
#          ...,
#          [184, 193, 196],
#          [184, 193, 196],
#          [182, 194, 196]]], dtype=uint8), array([[[220, 208, 189],
#          [220, 208, 189],
#          [220, 208, 189],
#          ...,
#          [221, 216, 204],
#          [222, 218, 205],
#          [223, 219, 206]],
#
#         [[218, 206, 187],
#          [218, 206, 187],
#          [218, 206, 187],
#          ...,
#          [223, 219, 206],
#          [225, 220, 207],
#          [226, 221, 208]],
#
#         [[215, 203, 185],
#          [215, 203, 185],
#          [215, 203, 185],
#          ...,
#          [226, 221, 208],
#          [226, 221, 208],
#          [226, 221, 208]],
#
#         ...,
#
#         [[136, 149, 151],
#          [136, 149, 151],
#          [137, 150, 152],
#          ...,
#          [139, 158, 162],
#          [139, 158, 162],
#          [139, 158, 162]],
#
#         [[136, 149, 151],
#          [136, 149, 151],
#          [137, 150, 152],
#          ...,
#          [143, 162, 165],
#          [143, 162, 165],
#          [143, 162, 165]],
#
#         [[135, 147, 150],
#          [135, 147, 150],
#          [136, 149, 151],
#          ...,
#          [144, 163, 167],
#          [144, 163, 167],
#          [144, 163, 167]]], dtype=uint8), array([[[ 99, 127, 144],
#          [101, 129, 146],
#          [103, 131, 148],
#          ...,
#          [168, 174, 181],
#          [168, 172, 177],
#          [167, 171, 176]],
#
#         [[ 99, 127, 144],
#          [101, 129, 146],
#          [103, 131, 148],
#          ...,
#          [168, 174, 181],
#          [168, 172, 177],
#          [167, 171, 176]],
#
#         [[ 99, 127, 144],
#          [101, 129, 146],
#          [103, 131, 148],
#          ...,
#          [168, 174, 181],
#          [168, 172, 177],
#          [167, 171, 176]],
#
#         ...,
#
#         [[ 81, 118, 146],
#          [ 83, 120, 148],
#          [ 86, 123, 151],
#          ...,
#          [152, 168, 184],
#          [150, 166, 182],
#          [149, 165, 181]],
#
#         [[ 79, 116, 144],
#          [ 81, 118, 146],
#          [ 83, 120, 148],
#          ...,
#          [152, 168, 184],
#          [150, 166, 182],
#          [149, 165, 181]],
#
#         [[ 76, 110, 139],
#          [ 78, 112, 141],
#          [ 79, 113, 142],
#          ...,
#          [154, 170, 186],
#          [152, 168, 184],
#          [150, 166, 182]]], dtype=uint8), array([[[209, 207, 207],
#          [209, 207, 207],
#          [210, 208, 208],
#          ...,
#          [187, 179, 179],
#          [188, 180, 180],
#          [188, 180, 180]],
#
#         [[210, 208, 208],
#          [210, 208, 208],
#          [210, 208, 208],
#          ...,
#          [187, 179, 179],
#          [188, 180, 180],
#          [189, 181, 181]],
#
#         [[210, 208, 208],
#          [210, 208, 208],
#          [210, 208, 208],
#          ...,
#          [187, 179, 179],
#          [188, 180, 180],
#          [189, 181, 181]],
#
#         ...,
#
#         [[141, 136, 133],
#          [140, 135, 132],
#          [149, 144, 141],
#          ...,
#          [141, 136, 133],
#          [142, 137, 134],
#          [143, 138, 135]],
#
#         [[150, 145, 142],
#          [140, 135, 132],
#          [145, 140, 137],
#          ...,
#          [142, 137, 136],
#          [144, 139, 138],
#          [145, 140, 139]],
#
#         [[162, 157, 154],
#          [141, 136, 133],
#          [141, 136, 133],
#          ...,
#          [142, 137, 136],
#          [145, 140, 139],
#          [146, 141, 140]]], dtype=uint8), array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]]], dtype=uint8), array([[[ 33,  30,  26],
#          [ 33,  30,  26],
#          [ 35,  32,  28],
#          ...,
#          [147, 145, 135],
#          [147, 145, 135],
#          [147, 145, 135]],
#
#         [[ 33,  30,  26],
#          [ 33,  30,  26],
#          [ 35,  32,  28],
#          ...,
#          [147, 145, 135],
#          [147, 145, 135],
#          [147, 145, 135]],
#
#         [[ 33,  30,  26],
#          [ 33,  30,  26],
#          [ 35,  32,  28],
#          ...,
#          [147, 145, 135],
#          [147, 145, 135],
#          [147, 145, 135]],
#
#         ...,
#
#         [[ 67, 133, 238],
#          [ 67, 133, 238],
#          [ 68, 134, 239],
#          ...,
#          [ 98, 149, 235],
#          [ 98, 149, 235],
#          [ 98, 149, 235]],
#
#         [[ 67, 133, 238],
#          [ 67, 133, 238],
#          [ 68, 134, 239],
#          ...,
#          [ 98, 149, 235],
#          [ 98, 149, 235],
#          [ 98, 149, 235]],
#
#         [[ 67, 133, 238],
#          [ 67, 133, 238],
#          [ 68, 134, 239],
#          ...,
#          [ 98, 149, 235],
#          [ 98, 149, 235],
#          [ 98, 149, 235]]], dtype=uint8), array([[[228, 228, 228],
#          [228, 228, 229],
#          [228, 228, 230],
#          ...,
#          [229, 229, 229],
#          [229, 229, 229],
#          [229, 229, 229]],
#
#         [[228, 228, 229],
#          [228, 228, 230],
#          [228, 229, 230],
#          ...,
#          [229, 229, 229],
#          [229, 229, 229],
#          [229, 229, 229]],
#
#         [[227, 229, 230],
#          [227, 229, 230],
#          [228, 229, 230],
#          ...,
#          [229, 229, 229],
#          [229, 229, 229],
#          [229, 229, 229]],
#
#         ...,
#
#         [[226, 225, 225],
#          [226, 225, 225],
#          [223, 224, 224],
#          ...,
#          [222, 225, 225],
#          [225, 226, 225],
#          [226, 226, 226]],
#
#         [[224, 224, 224],
#          [224, 224, 224],
#          [223, 224, 224],
#          ...,
#          [216, 221, 221],
#          [223, 225, 225],
#          [226, 226, 226]],
#
#         [[223, 224, 224],
#          [224, 224, 224],
#          [223, 223, 223],
#          ...,
#          [212, 215, 218],
#          [221, 223, 223],
#          [225, 225, 225]]], dtype=uint8), array([[[254, 249, 250],
#          [255, 250, 251],
#          [255, 250, 251],
#          ...,
#          [ 34,  47,  55],
#          [ 36,  45,  58],
#          [ 40,  47,  62]],
#
#         [[254, 249, 250],
#          [255, 250, 251],
#          [255, 250, 251],
#          ...,
#          [ 29,  41,  51],
#          [ 35,  42,  57],
#          [ 42,  46,  64]],
#
#         [[252, 250, 250],
#          [253, 251, 251],
#          [253, 251, 251],
#          ...,
#          [ 27,  36,  50],
#          [ 33,  40,  57],
#          [ 41,  44,  65]],
#
#         ...,
#
#         [[190, 195, 196],
#          [191, 196, 197],
#          [191, 196, 197],
#          ...,
#          [193, 198, 199],
#          [193, 198, 199],
#          [194, 199, 200]],
#
#         [[192, 197, 198],
#          [191, 196, 197],
#          [189, 194, 195],
#          ...,
#          [192, 197, 200],
#          [193, 198, 201],
#          [193, 198, 201]],
#
#         [[194, 199, 200],
#          [192, 197, 198],
#          [189, 194, 195],
#          ...,
#          [190, 197, 200],
#          [191, 198, 201],
#          [191, 198, 201]]], dtype=uint8), array([[[130, 100,  71],
#          [129,  99,  70],
#          [130, 100,  72],
#          ...,
#          [ 92,  82,  74],
#          [ 91,  81,  73],
#          [ 90,  80,  72]],
#
#         [[130, 100,  71],
#          [129,  99,  70],
#          [130,  99,  71],
#          ...,
#          [ 91,  79,  72],
#          [ 92,  78,  72],
#          [ 90,  81,  72]],
#
#         [[129,  99,  70],
#          [130, 100,  71],
#          [131, 100,  72],
#          ...,
#          [ 92,  76,  71],
#          [ 92,  78,  72],
#          [ 90,  81,  72]],
#
#         ...,
#
#         [[101, 140, 165],
#          [ 97, 134, 160],
#          [ 96, 137, 162],
#          ...,
#          [120, 163, 190],
#          [134, 174, 198],
#          [143, 180, 202]],
#
#         [[ 89, 121, 145],
#          [ 90, 119, 141],
#          [ 77, 110, 132],
#          ...,
#          [129, 164, 191],
#          [130, 168, 194],
#          [132, 169, 193]],
#
#         [[ 77, 113, 136],
#          [ 65,  97, 116],
#          [ 64,  95, 115],
#          ...,
#          [112, 155, 182],
#          [128, 165, 191],
#          [138, 173, 196]]], dtype=uint8)]

# %% [markdown]
# add_from_data

# %%
dwell = take_data('images').store_filesnames_from_list(flist[:10])
print(dwell)
# Out:
# Object <class 'cytokine.data.Data'>, of data type "images", having 10 file paths records.

# %%
a2 = take_data('images').store_filesnames_from_list(flist[5:20])
print(a2)
# Out:
# Object <class 'cytokine.data.Data'>, of data type "images", having 15 file paths records.

# %%
dwell.add_from_data(a2)
print(dwell)
# Out:
# Object <class 'cytokine.data.Data'>, of data type "images", having 20 file paths records.

# %% [markdown]
# expel_to

# %% [markdown]
# ### Expell

# %%
c = take_data('images').store_filesnames_from_folder('./cytokine/tests/mocks/imgs/dog')
c.filesnames.head()
# Out:
# 0      ./cytokine/tests/mocks/imgs/dog/dog_5.png
# 1     ./cytokine/tests/mocks/imgs/dog/dog_16.jpg
# 2    ./cytokine/tests/mocks/imgs/dog/dog_32.jpeg
# 3     ./cytokine/tests/mocks/imgs/dog/dog_17.jpg
# 4     ./cytokine/tests/mocks/imgs/dog/dog_22.jpg
# Name: data1577554295202254, dtype: object

# %%
# path = './cytokine/tests/mocks/imgs/bin/'
# inthisnewfolder = 'new_images'
# namefilesas = None
# c.expell_to(path, inthisnewfolder, namefilesas)

# %% [markdown]
# expell_to: namefilesas 'data'

# %%
# path = './cytokine/tests/mocks/imgs/bin/'
# inthisnewfolder = 'new_images2'
# namefilesas = 'data'
# c.expell_to(path, inthisnewfolder, namefilesas)

# %% [markdown]
# expell_to: namefilesas 'folder'

# %%
# path = './cytokine/tests/mocks/imgs/bin/'
# inthisnewfolder = 'new_images3'
# namefilesas = 'folder'
# c.expell_to(path, inthisnewfolder, namefilesas)

# %% [markdown]
# _____

# %% [markdown]
# ## Export

# %% [markdown]
# #### to Keras ImageDataGenerator

# %%
ke_gen = c.export_to_keras();
# Out:
# /home/gian/anaconda3/envs/py38ml/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/gian/anaconda3/envs/py38ml/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/gian/anaconda3/envs/py38ml/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/gian/anaconda3/envs/py38ml/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/gian/anaconda3/envs/py38ml/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/gian/anaconda3/envs/py38ml/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Found 36 validated image filenames belonging to 1 classes.

# %% [markdown]
# it also accepts arguments

# %%
idg = {
    'rescale': 1./255,
    'shear_range': 0.2,
    'zoom_range': 0.2,
    'horizontal_flip': True
}
ke_gen = c.export_to_keras(imagedatagenerator_args=idg)
# Out:
# Found 36 validated image filenames belonging to 1 classes.

# %%
type(ke_gen)
# Out:
# keras_preprocessing.image.dataframe_iterator.DataFrameIterator

# %% [markdown]
# #### to FastAI

# %%
c.length()
# Out:
# 36

# %%
c.filesnames_to_ml_df().head()
# Out:
#                           data1577554295202254                     y
# 0    ./cytokine/tests/mocks/imgs/dog/dog_5.png  data1577554295202254
# 1   ./cytokine/tests/mocks/imgs/dog/dog_16.jpg  data1577554295202254
# 2  ./cytokine/tests/mocks/imgs/dog/dog_32.jpeg  data1577554295202254
# 3   ./cytokine/tests/mocks/imgs/dog/dog_17.jpg  data1577554295202254
# 4   ./cytokine/tests/mocks/imgs/dog/dog_22.jpg  data1577554295202254

# %%
from fastai.vision import ImageDataBunch,ImageList
from fastai.vision.transform import get_transforms
# https://docs.fast.ai/vision.data.html#ImageDataBunch.from_df
# fastai_gen = ImageDataBunch.from_df(path, df, ds_tfms=tfms, size=24)
tfms_arg = get_transforms() # https://docs.fast.ai/vision.transform.html
idb_args = {
    'ds_tfms': tfms_arg,
    'valid_pct': 0,
    'bs': 40,
#     'label_col': None, #label column
}
#fastai_idb = ImageDataBunch.from_df(path='',df=c.filesnames_to_ml_df(), valid_pct=0, bs=40)


fastai_idb = a.export_to_fastAI(imagedatabunch_args=idb_args)
fastai_idb
# Out:
# /home/gian/anaconda3/envs/py38ml/lib/python3.7/site-packages/fastai/basic_data.py:262: UserWarning: There seems to be something wrong with your dataset, for example, in the first batch can't access these elements in self.train_ds: 36
#   warn(warn_msg)
# You can deactivate this warning by passing `no_check=True`.
# ImageDataBunch;
#
# Train: LabelList (76 items)
# x: ImageList
# Image (3, 1414, 2121),Image (3, 600, 800),Image (3, 1944, 2592),Image (3, 546, 970),Image (3, 405, 720)
# y: CategoryList
# data15775542847713625,data15775542847713625,data15775542847713625,data15775542847713625,data15775542847713625
# Path: .;
#
# Valid: LabelList (0 items)
# x: ImageList
#
# y: CategoryList
#
# Path: .;
#
# Test: None

# %%
type(fastai_idb)
# Out:
# fastai.vision.data.ImageDataBunch

# %%
fastai_idb.open( fastai_idb.items[1] )
# Out:
# Image (3, 600, 800)

# %% [markdown]
# #### to Pytorch

# %%
#https://stanford.edu/~shervine/blog/pytorch-how-to-generate-data-parallel

# %%
doggo = './cytokine/tests/mocks/imgs/dog'

splitta = lambda x: os.path.split(x)[0]
paths = list(set(c.filesnames.apply(splitta)))
paths
# iml1 = ImageList.from_df(doggo);
# iml1
# Out:
# ['./cytokine/tests/mocks/imgs/dog']

# %%
c.filesnames.apply(splitta)
# Out:
# 0     ./cytokine/tests/mocks/imgs/dog
# 1     ./cytokine/tests/mocks/imgs/dog
# 2     ./cytokine/tests/mocks/imgs/dog
# 3     ./cytokine/tests/mocks/imgs/dog
# 4     ./cytokine/tests/mocks/imgs/dog
# 5     ./cytokine/tests/mocks/imgs/dog
# 6     ./cytokine/tests/mocks/imgs/dog
# 7     ./cytokine/tests/mocks/imgs/dog
# 8     ./cytokine/tests/mocks/imgs/dog
# 9     ./cytokine/tests/mocks/imgs/dog
# 10    ./cytokine/tests/mocks/imgs/dog
# 11    ./cytokine/tests/mocks/imgs/dog
# 12    ./cytokine/tests/mocks/imgs/dog
# 13    ./cytokine/tests/mocks/imgs/dog
# 14    ./cytokine/tests/mocks/imgs/dog
# 15    ./cytokine/tests/mocks/imgs/dog
# 16    ./cytokine/tests/mocks/imgs/dog
# 17    ./cytokine/tests/mocks/imgs/dog
# 18    ./cytokine/tests/mocks/imgs/dog
# 19    ./cytokine/tests/mocks/imgs/dog
# 20    ./cytokine/tests/mocks/imgs/dog
# 21    ./cytokine/tests/mocks/imgs/dog
# 22    ./cytokine/tests/mocks/imgs/dog
# 23    ./cytokine/tests/mocks/imgs/dog
# 24    ./cytokine/tests/mocks/imgs/dog
# 25    ./cytokine/tests/mocks/imgs/dog
# 26    ./cytokine/tests/mocks/imgs/dog
# 27    ./cytokine/tests/mocks/imgs/dog
# 28    ./cytokine/tests/mocks/imgs/dog
# 29    ./cytokine/tests/mocks/imgs/dog
# 30    ./cytokine/tests/mocks/imgs/dog
# 31    ./cytokine/tests/mocks/imgs/dog
# 32    ./cytokine/tests/mocks/imgs/dog
# 33    ./cytokine/tests/mocks/imgs/dog
# 34    ./cytokine/tests/mocks/imgs/dog
# 35    ./cytokine/tests/mocks/imgs/dog
# Name: data1577554295202254, dtype: object

# %%
a = pd.DataFrame()
a['c1'] = c.filesnames
a['c2'] = c.filesnames
a.head()
# Out:
#                                             c1  \
# 0    ./cytokine/tests/mocks/imgs/dog/dog_5.png
# 1   ./cytokine/tests/mocks/imgs/dog/dog_16.jpg
# 2  ./cytokine/tests/mocks/imgs/dog/dog_32.jpeg
# 3   ./cytokine/tests/mocks/imgs/dog/dog_17.jpg
# 4   ./cytokine/tests/mocks/imgs/dog/dog_22.jpg
#
#                                             c2
# 0    ./cytokine/tests/mocks/imgs/dog/dog_5.png
# 1   ./cytokine/tests/mocks/imgs/dog/dog_16.jpg
# 2  ./cytokine/tests/mocks/imgs/dog/dog_32.jpeg
# 3   ./cytokine/tests/mocks/imgs/dog/dog_17.jpg
# 4   ./cytokine/tests/mocks/imgs/dog/dog_22.jpg
